# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Dealing with and or converting missing or ill-formated data into a format that more easily lends itself to analysis

# %% [markdown]
# ### Most common Data Formats:
#
# 1) CSV
#
# 2) XML
#
# 3) JSON

# %% [markdown]
# ## Baseball Database
#
# http://seanlahman.com/baseball-archive/statistics

# %%
import numpy as np
import pandas as pd
import os

# %%
input_dir = os.getcwd() + '/data/input/'
output_dir = os.getcwd() + '/data/output/'

# %%
baseball_data = pd.read_csv(input_dir + 'baseballdatabank-2017.1/core/Master.csv')

# %%
print (baseball_data['nameFirst'])
# Out:
# 0           David
# 1            Hank
# 2          Tommie
# 3             Don
# 4            Andy
# 5        Fernando
# 6            John
# 7              Ed
# 8            Bert
# 9         Charlie
# 10            Dan
# 11           Fred
# 12          Glenn
# 13           Jeff
# 14            Jim
# 15           Kurt
# 16           Kyle
# 17            Ody
# 18           Paul
# 19             Al
# 20          Frank
# 21         Reggie
# 22           Bill
# 23          Brent
# 24            Ted
# 25            Ted
# 26          Woody
# 27          Cliff
# 28          Harry
# 29          Shawn
#            ...
# 19075      Jordan
# 19076         Roy
# 19077        Ryan
# 19078     Charlie
# 19079      Walter
# 19080       Frank
# 19081         Guy
# 19082       Jimmy
# 19083        Bill
# 19084        Alan
# 19085         Bud
# 19086      Richie
# 19087       Barry
# 19088       Billy
# 19089          Ed
# 19090         Ben
# 19091       Peter
# 19092         Sam
# 19093       Eddie
# 19094        Bill
# 19095         Jon
# 19096       Julio
# 19097        Joel
# 19098        Mike
# 19099         Bob
# 19100       Frank
# 19101        Paul
# 19102      George
# 19103       Dutch
# 19104        Tony
# Name: nameFirst, Length: 19105, dtype: object

# %% [markdown]
# ### Add a new column

# %%
baseball_data['height_plus_weight'] = baseball_data['height'] + baseball_data['weight']

# %%
print (baseball_data['height_plus_weight'])
# Out:
# 0        290.0
# 1        252.0
# 2        265.0
# 3        265.0
# 4        257.0
# 5        293.0
# 6        264.0
# 7        241.0
# 8        246.0
# 9        237.0
# 10       261.0
# 11       250.0
# 12       278.0
# 13       264.0
# 14       275.0
# 15       251.0
# 16       276.0
# 17       254.0
# 18       260.0
# 19       269.0
# 20         NaN
# 21       290.0
# 22       260.0
# 23       258.0
# 24       284.0
# 25       291.0
# 26       242.0
# 27       272.0
# 28       274.0
# 29       263.0
#          ...
# 19075    299.0
# 19076    261.0
# 19077    300.0
# 19078    263.0
# 19079    237.0
# 19080    218.0
# 19081    240.0
# 19082    267.0
# 19083    258.0
# 19084    274.0
# 19085    275.0
# 19086    273.0
# 19087    279.0
# 19088    245.0
# 19089    252.0
# 19090    285.0
# 19091    274.0
# 19092    256.0
# 19093    247.0
# 19094    269.0
# 19095    263.0
# 19096    308.0
# 19097    290.0
# 19098    294.0
# 19099    296.0
# 19100    253.0
# 19101    245.0
# 19102    271.0
# 19103    226.0
# 19104    265.0
# Name: height_plus_weight, Length: 19105, dtype: float64

# %% [markdown]
# ### Export the new DataFrame to CSV (with weight-height sum column)
#
# For more info: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html

# %%
baseball_data.to_csv(output_dir + 'baseball_data_with_weight_height_sum.csv')

# %% [markdown]
# # Data Wrangling - Lesson 3 Quiz

# %%
def add_full_name(path_to_csv, path_to_new_csv):
    
    baseball_data = pd.read_csv(path_to_csv)
    baseball_data['nameFull'] = baseball_data['nameFirst'] + " " + baseball_data['nameLast']
    
    baseball_data.to_csv(path_to_new_csv)

# %%
path_to_csv = input_dir + '/baseballdatabank-2017.1/core/Master.csv'
path_to_new_csv = output_dir + 'baseball_data_with_fullname.csv'

add_full_name(path_to_csv, path_to_new_csv)

# %% [markdown]
# # Working with Relational Databases using Pandasql
#
# 1) It is straight forward to extract aggregated data with complex filters
#
# 2) A database scales well
#
# 3) It ensures all data is consistently formatted (each column, one format)

# %% [markdown]
# ## Aadhaar Data - Lesson 3 Quiz
#
# https://s3.amazonaws.com/content.udacity-data.com/courses/ud359/aadhaar_data.csv

# %% [markdown]
# ### SQL queries with pandasql

# %%
import pandasql as pdsql

# %% [markdown]
# ### Read csv file function

# %%
def read_csv_data(filename):
    '''
    Receives a file name (csv)
    Returns a DataFrame
    '''
    data = pd.read_csv(input_dir + filename)
    
    #Rename the columns by replacing spaces with underscores and setting all characters to lowercase
    data.rename(columns = lambda x: x.replace(' ', '_').lower(), inplace=True)
    
    return data

# %%
def exe_sql_query(data, query):
    '''
    Receives a DataFrame and a String (SQL query)
    Execute SQL query and returns a DataFrame
    '''
    #Rename the columns by replacing spaces with underscores and setting all characters to lowercase
    data.rename(columns = lambda x: x.replace(' ', '_').lower(), inplace=True)

    q = """
        {0}
    """.format(query)

    #Execute your SQL command against the pandas frame
    # OBS: case sensitive
    solution = pdsql.sqldf(q, locals())
    return solution

# %% [markdown]
# #### Read data

# %%
aadhaar_data = read_csv_data('aadhaar-data.csv')

# %%
aadhaar_data.loc[3]
# Out:
# registrar                                         Allahabad Bank
# enrolment_agency                     Vakrangee Softwares Limited
# state                                           Himachal Pradesh
# district                                                  Kangra
# sub_district                                            Baijnath
# pin_code                                                  176081
# gender                                                         M
# age                                                           44
# aadhaar_generated                                              1
# enrolment_rejected                                             0
# residents_providing_email                                      1
# residents_providing_mobile_number                              1
# Name: 3, dtype: object

# %%
aadhaar_data.loc[[0,1,3,5,7]]
# Out:
#         registrar             enrolment_agency             state    district  \
# 0  Allahabad Bank            Tera Software Ltd         Jharkhand      Ranchi
# 1  Allahabad Bank            Tera Software Ltd         Jharkhand      Ranchi
# 3  Allahabad Bank  Vakrangee Softwares Limited  Himachal Pradesh      Kangra
# 5  Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 7  Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
#
#   sub_district pin_code gender  age  aadhaar_generated  enrolment_rejected  \
# 0       Namkum   834003      M   63                  0                   1
# 1       Ranchi   834004      F   36                  0                   1
# 3     Baijnath   176081      M   44                  1                   0
# 5       Nevasa   414105      M   28                  1                   0
# 7        Rahta   423107      F    9                  0                   1
#
#    residents_providing_email  residents_providing_mobile_number
# 0                          0                                  1
# 1                          0                                  1
# 3                          1                                  1
# 5                          0                                  0
# 7                          0                                  0

# %% [markdown]
# ### Select
#
# Select first 10

# %%
# Select out the first 10 values for "registrar" and "enrolment_agency"
# in the aadhaar_data table using SQL syntax. 
query = """
    SELECT registrar, enrolment_agency FROM data LIMIT 10;
"""
exe_sql_query(aadhaar_data, query)
# Out:
#         registrar             enrolment_agency
# 0  Allahabad Bank            Tera Software Ltd
# 1  Allahabad Bank            Tera Software Ltd
# 2  Allahabad Bank  Vakrangee Softwares Limited
# 3  Allahabad Bank  Vakrangee Softwares Limited
# 4  Allahabad Bank  Vakrangee Softwares Limited
# 5  Allahabad Bank  Vakrangee Softwares Limited
# 6  Allahabad Bank  Vakrangee Softwares Limited
# 7  Allahabad Bank  Vakrangee Softwares Limited
# 8  Allahabad Bank  Vakrangee Softwares Limited
# 9  Allahabad Bank  Vakrangee Softwares Limited

# %% [markdown]
# ### Select + Where

# %%
state = 'Gujarat'
limit = 10
query = """
    SELECT * FROM data WHERE state = '{0}' LIMIT {1};
""".format(state,limit)

exe_sql_query(aadhaar_data, query)
# Out:
#         registrar                enrolment_agency    state        district  \
# 0  Allahabad Bank     Vakrangee Softwares Limited  Gujarat           Surat
# 1   Bank Of India      CHESSY CONSULTANTS PVT LTD  Gujarat       Ahmedabad
# 2   Bank Of India      CHESSY CONSULTANTS PVT LTD  Gujarat          Amreli
# 3   Bank Of India      CHESSY CONSULTANTS PVT LTD  Gujarat          Amreli
# 4   Bank Of India      CHESSY CONSULTANTS PVT LTD  Gujarat        Junagadh
# 5   Bank Of India      CHESSY CONSULTANTS PVT LTD  Gujarat         Kachchh
# 6   Bank Of India      CHESSY CONSULTANTS PVT LTD  Gujarat         Kachchh
# 7   Bank Of India        Frontech Systems Pvt Ltd  Gujarat        Junagadh
# 8   Bank Of India        Frontech Systems Pvt Ltd  Gujarat  Surendra Nagar
# 9   Bank Of India  MANTRA SOFTTECH (INDIA) PVTLTD  Gujarat       Ahmedabad
#
#      sub_district pin_code gender  age  aadhaar_generated  enrolment_rejected  \
# 0           Nizar   394380      M   10                  1                   0
# 1  Ahmadabad City   380050      F   61                  1                   0
# 2          Rajula   365560      F   34                  1                   0
# 3          Rajula   365560      M   38                  1                   0
# 4   Patan Veraval   362268      F   35                  1                   0
# 5           Rapar   370145      M    9                  1                   0
# 6           Rapar   370165      M   20                  1                   0
# 7         Kodinar   362720      M   25                  1                   0
# 8           Sayla   363430      F   27                  1                   0
# 9  Ahmadabad City   380004      M    7                  1                   0
#
#    residents_providing_email  residents_providing_mobile_number
# 0                          0                                  0
# 1                          0                                  1
# 2                          0                                  1
# 3                          0                                  1
# 4                          0                                  1
# 5                          0                                  1
# 6                          0                                  1
# 7                          0                                  1
# 8                          0                                  1
# 9                          0                                  1

# %% [markdown]
# ### Useful functions

# %% [markdown]
# #### SUM and GROUP BY functions

# %% [markdown]
# * Total number of enrolments(aadhaar_generated)/state and group by state
#
# ##### GROUP BY:
# * Givesthe sum of [column_name] 'for_each' [column name]

# %%
query = """
    SELECT state, SUM(aadhaar_generated) FROM data GROUP BY state;
"""

exe_sql_query(aadhaar_data, query)
# Out:
#                      state  SUM(aadhaar_generated)
# 0           Andhra Pradesh                     820
# 1        Arunachal Pradesh                       4
# 2                    Assam                      34
# 3                    Bihar                     622
# 4               Chandigarh                      31
# 5             Chhattisgarh                      28
# 6   Dadra and Nagar Haveli                       1
# 7                    Delhi                    1025
# 8                  Gujarat                      85
# 9                  Haryana                   19480
# 10        Himachal Pradesh                     129
# 11       Jammu and Kashmir                      49
# 12               Jharkhand                   25089
# 13               Karnataka                   14737
# 14                  Kerala                      29
# 15          Madhya Pradesh                   88557
# 16             Maharashtra                   20042
# 17                 Manipur                       3
# 18               Meghalaya                       1
# 19                  Odisha                     119
# 20                  Others                      62
# 21              Puducherry                      18
# 22                  Punjab                    8466
# 23               Rajasthan                   11362
# 24              Tamil Nadu                     212
# 25                 Tripura                     753
# 26           Uttar Pradesh                     977
# 27             Uttarakhand                      63
# 28             West Bengal                     203

# %% [markdown]
# * Total number of enrolments(aadhaar_generated)/district and sub_district and group by district/sub_district

# %%
query = """
    SELECT district, sub_district, SUM(aadhaar_generated) FROM data GROUP BY district, sub_district;
"""

exe_sql_query(aadhaar_data, query)
# Out:
#             district          sub_district  SUM(aadhaar_generated)
# 0           Adilabad            Lokeswaram                       1
# 1               Agra                   Bah                       3
# 2               Agra              Etmadpur                       1
# 3               Agra             Fatehabad                       1
# 4               Agra             Kheragarh                       2
# 5               Agra               Kiraoli                       2
# 6         Ahmadnagar                 Akola                       3
# 7         Ahmadnagar               Jamkhed                       2
# 8         Ahmadnagar                Karjat                       3
# 9         Ahmadnagar             Kopargaon                       4
# 10        Ahmadnagar                 Nagar                       4
# 11        Ahmadnagar                Nevasa                     139
# 12        Ahmadnagar                Parner                       5
# 13        Ahmadnagar              Pathardi                     114
# 14        Ahmadnagar                 Rahta                       1
# 15        Ahmadnagar                Rahuri                     123
# 16        Ahmadnagar             Sangamner                       2
# 17        Ahmadnagar              Shevgaon                     120
# 18        Ahmadnagar             Shrigonda                      32
# 19       Ahmed Nagar                Karjat                       0
# 20       Ahmed Nagar             Kopargaon                       0
# 21       Ahmed Nagar                 Nagar                       0
# 22       Ahmed Nagar              Pathardi                       0
# 23       Ahmed Nagar                 Rahta                       0
# 24       Ahmed Nagar                Rahuri                       0
# 25         Ahmedabad        Ahmadabad City                       8
# 26         Ahmedabad               Daskroi                       1
# 27             Ajmer                 Ajmer                       1
# 28             Ajmer                Beawar                      29
# 29             Ajmer                Bhinay                      19
# ...              ...                   ...                     ...
# 2440  West Singhbhum              Majhgaon                     289
# 2441  West Singhbhum              Manjhari                       1
# 2442  West Singhbhum            Manoharpur                     227
# 2443  West Singhbhum  Noamundi (barajamda)                     827
# 2444  West Singhbhum                 Sonua                     109
# 2445  West Singhbhum             Tantnagar                       7
# 2446  West Singhbhum                 Tonto                     406
# 2447    West Tripura        Agartala Sadar                     112
# 2448    West Tripura                 Dukli                      24
# 2449    West Tripura              Hezamara                      42
# 2450    West Tripura               Jirania                     101
# 2451    West Tripura                Mandai                      44
# 2452    West Tripura              Mohanpur                      69
# 2453          Yadgir               Shahpur                      42
# 2454          Yadgir              Shorapur                      25
# 2455          Yadgir                Yadgir                       2
# 2456    Yamuna Nagar          Chhachhrauli                     148
# 2457    Yamuna Nagar              Jagadhri                    1438
# 2458        Yavatmal                  Arni                      13
# 2459        Yavatmal             Babulgaon                      49
# 2460        Yavatmal                Digras                       4
# 2461        Yavatmal              Ghatanji                      43
# 2462        Yavatmal                Kalamb                     189
# 2463        Yavatmal               Kelapur                       9
# 2464        Yavatmal              Mahagaon                      36
# 2465        Yavatmal                 Pusad                      33
# 2466        Yavatmal              Ralegaon                      24
# 2467        Yavatmal              Umarkhed                      34
# 2468        Yavatmal              Yavatmal                      34
# 2469        Yavatmal           Zari-Jamani                       1
#
# [2470 rows x 3 columns]

# %% [markdown]
# * using WHERE

# %%
query = """
    SELECT district, sub_district, SUM(aadhaar_generated) FROM data WHERE age > 60 GROUP BY district, sub_district;
"""

exe_sql_query(aadhaar_data, query)
# Out:
#            district          sub_district  SUM(aadhaar_generated)
# 0        Ahmadnagar                 Nagar                       0
# 1        Ahmadnagar                Nevasa                      18
# 2        Ahmadnagar                Parner                       1
# 3        Ahmadnagar              Pathardi                      13
# 4        Ahmadnagar                 Rahta                       0
# 5        Ahmadnagar                Rahuri                       5
# 6        Ahmadnagar              Shevgaon                      23
# 7        Ahmadnagar             Shrigonda                       3
# 8       Ahmed Nagar             Kopargaon                       0
# 9       Ahmed Nagar                 Nagar                       0
# 10        Ahmedabad        Ahmadabad City                       1
# 11            Ajmer                Beawar                       3
# 12            Ajmer                Bhinay                       1
# 13            Ajmer                 Kekri                      17
# 14            Ajmer            Kishangarh                       3
# 15            Ajmer             Peesangan                       1
# 16            Ajmer                Sarwar                      16
# 17            Akola               Balapur                       2
# 18            Akola               Telhara                       1
# 19        Alirajpur                Bhavra                      32
# 20        Alirajpur                 Jobat                      16
# 21        Allahabad             Allahabad                       9
# 22        Allahabad                  Bara                       1
# 23        Allahabad                Koraon                       1
# 24            Alwar                 Alwar                       1
# 25            Alwar                Behror                       5
# 26            Alwar              Kathumar                       1
# 27            Alwar        Kishangarh Bas                       6
# 28            Alwar              Kotkasim                       1
# 29            Alwar               Rajgarh                       0
# ..              ...                   ...                     ...
# 879  West Singhbhum         Chakradharpur                      15
# 880  West Singhbhum              Goilkera                       8
# 881  West Singhbhum          Jagannathpur                      26
# 882  West Singhbhum             Jhinkpani                       2
# 883  West Singhbhum             Khuntpani                      13
# 884  West Singhbhum            Kumardungi                      14
# 885  West Singhbhum              Majhgaon                      12
# 886  West Singhbhum            Manoharpur                       9
# 887  West Singhbhum  Noamundi (barajamda)                      37
# 888  West Singhbhum                 Sonua                      10
# 889  West Singhbhum             Tantnagar                       0
# 890  West Singhbhum                 Tonto                      16
# 891    West Tripura        Agartala Sadar                       6
# 892    West Tripura                 Dukli                       1
# 893    West Tripura              Hezamara                       2
# 894    West Tripura               Jirania                       6
# 895    West Tripura              Mohanpur                       2
# 896          Yadgir               Shahpur                       9
# 897    Yamuna Nagar          Chhachhrauli                      12
# 898    Yamuna Nagar              Jagadhri                     131
# 899        Yavatmal                  Arni                       2
# 900        Yavatmal             Babulgaon                      11
# 901        Yavatmal                Digras                       0
# 902        Yavatmal              Ghatanji                       3
# 903        Yavatmal                Kalamb                      24
# 904        Yavatmal              Mahagaon                       5
# 905        Yavatmal                 Pusad                       2
# 906        Yavatmal              Ralegaon                       1
# 907        Yavatmal              Umarkhed                       6
# 908        Yavatmal              Yavatmal                       3
#
# [909 rows x 3 columns]

# %% [markdown]
# ## Create a Query - Lesson 3 Quiz
# Write a query that will select from the aadhaar_data table how many men and how many women over the age of 50 have had aadhaar generated for them in each district. aadhaar_generated is a column in the Aadhaar Data that denotes the number who have had aadhaar generated in each row of the table.

# %%
# gives the sum of aadhaar_generated for each gender-district pair
query = """
    SELECT gender, district, SUM(aadhaar_generated) 
    FROM data 
    WHERE age > 50
    GROUP BY gender, district;
"""

exe_sql_query(aadhaar_data, query)
# Out:
#     gender           district  SUM(aadhaar_generated)
# 0        F         Ahmadnagar                      45
# 1        F        Ahmed Nagar                       0
# 2        F          Ahmedabad                       1
# 3        F              Ajmer                      27
# 4        F              Akola                       5
# 5        F          Alirajpur                      71
# 6        F          Allahabad                      15
# 7        F              Alwar                      14
# 8        F             Ambala                       7
# 9        F           Amravati                       0
# 10       F           Amritsar                      30
# 11       F            Anuppur                     101
# 12       F        Ashok Nagar                       1
# 13       F         Aurangabad                      19
# 14       F           Balaghat                     287
# 15       F          Bangalore                     433
# 16       F    Bangalore Rural                       9
# 17       F              Banka                       0
# 18       F           Banswara                      28
# 19       F              Baran                       5
# 20       F            Barwani                      34
# 21       F           Bathinda                      43
# 22       F               Beed                      25
# 23       F            Belgaum                      59
# 24       F            Bellary                      65
# 25       F              Betul                      41
# 26       F          Bhagalpur                       0
# 27       F           Bhandara                       4
# 28       F          Bharatpur                      94
# 29       F           Bhilwara                      50
# ..     ...                ...                     ...
# 498      M              Sirsa                     158
# 499      M            Solapur                      80
# 500      M          Sonbhadra                       7
# 501      M            Sonipat                      14
# 502      M        South Delhi                       5
# 503      M      South Tripura                       0
# 504      M   South West Delhi                       4
# 505      M  Sri Muktsar Sahib                      21
# 506      M         Tarn Taran                     125
# 507      M              Thane                     144
# 508      M          Tikamgarh                     265
# 509      M     Tiruvannamalai                       1
# 510      M               Tonk                      49
# 511      M             Tumkur                       1
# 512      M            Udaipur                      16
# 513      M             Ujjain                      66
# 514      M             Umaria                     137
# 515      M                Una                       3
# 516      M             Valsad                       2
# 517      M            Vellore                       0
# 518      M            Vidisha                      84
# 519      M         Viluppuram                      18
# 520      M             Wardha                       1
# 521      M             Washim                      33
# 522      M         West Delhi                       3
# 523      M     West Singhbhum                     227
# 524      M       West Tripura                      24
# 525      M             Yadgir                      12
# 526      M       Yamuna Nagar                     149
# 527      M           Yavatmal                      54
#
# [528 rows x 3 columns]

# %% [markdown]
# # API's (Application Programming Interface)
#
# https://www.last.fm/api
# -> http://ws.audioscrobbler.com/2.0/?method=album.getinfo&api_key=[API_KEY]&artist=Weezer&album=Pikerton&format=json

# %%
import json
import requests

# %% [markdown]
# ## Using PrettyPrinter
#
# https://docs.python.org/2/library/pprint.html

# %%
import pprint

pp = pprint.PrettyPrinter(indent=2)

# %% [markdown]
# ## Get Data

# %%
def get_data_api(url, return_type):
    data = requests.get(url).text
    
    if return_type.lower() == 'json':
        data = json.loads(data)

    return data

# %%
method = 'album.getinfo'

artist = 'Weezer'
album = 'Pinkerton'
url = 'http://ws.audioscrobbler.com/2.0/?method={0}&api_key=4beab33cc6d65b05800d51f5e83bde1b&artist={1}&album={2}&format=json'.format(method,artist,album)

lastfm_data = get_data_api(url,'JSON')
print (type(lastfm_data))
pp.pprint (lastfm_data)
# Out:
# <class 'dict'>
# { 'album': { 'artist': 'Weezer',
#              'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/d83c358e97c7460ec636f27c315aa562.png',
#                           'size': 'small'},
#                         { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/d83c358e97c7460ec636f27c315aa562.png',
#                           'size': 'medium'},
#                         { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/d83c358e97c7460ec636f27c315aa562.png',
#                           'size': 'large'},
#                         { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/d83c358e97c7460ec636f27c315aa562.png',
#                           'size': 'extralarge'},
#                         { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/d83c358e97c7460ec636f27c315aa562.png',
#                           'size': 'mega'},
#                         { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/d83c358e97c7460ec636f27c315aa562.png',
#                           'size': ''}],
#              'listeners': '637882',
#              'mbid': 'ef968db8-874e-4d79-adb7-2ea0fe0b2b76',
#              'name': 'Pinkerton',
#              'playcount': '11663989',
#              'tags': { 'tag': [ { 'name': 'albums I own',
#                                   'url': 'https://www.last.fm/tag/albums+I+own'},
#                                 { 'name': 'alternative rock',
#                                   'url': 'https://www.last.fm/tag/alternative+rock'},
#                                 { 'name': 'favorite albums',
#                                   'url': 'https://www.last.fm/tag/favorite+albums'},
#                                 { 'name': '90s',
#                                   'url': 'https://www.last.fm/tag/90s'},
#                                 { 'name': '1996',
#                                   'url': 'https://www.last.fm/tag/1996'}]},
#              'tracks': { 'track': [ { '@attr': {'rank': '1'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '181',
#                                       'name': 'Tired of Sex',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/Tired+of+Sex'},
#                                     { '@attr': {'rank': '2'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '172',
#                                       'name': 'Getchoo',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/Getchoo'},
#                                     { '@attr': {'rank': '3'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '181',
#                                       'name': 'No Other One',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/No+Other+One'},
#                                     { '@attr': {'rank': '4'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '128',
#                                       'name': 'Why Bother?',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/Why+Bother%3F'},
#                                     { '@attr': {'rank': '5'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '272',
#                                       'name': 'Across the Sea',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/Across+the+Sea'},
#                                     { '@attr': {'rank': '6'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '257',
#                                       'name': 'The Good Life',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/The+Good+Life'},
#                                     { '@attr': {'rank': '7'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '243',
#                                       'name': 'El Scorcho',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/El+Scorcho'},
#                                     { '@attr': {'rank': '8'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '238',
#                                       'name': 'Pink Triangle',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/Pink+Triangle'},
#                                     { '@attr': {'rank': '9'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '227',
#                                       'name': 'Falling for You',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/Falling+for+You'},
#                                     { '@attr': {'rank': '10'},
#                                       'artist': { 'mbid': '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#                                                   'name': 'Weezer',
#                                                   'url': 'https://www.last.fm/music/Weezer'},
#                                       'duration': '173',
#                                       'name': 'Butterfly',
#                                       'streamable': { '#text': '0',
#                                                       'fulltrack': '0'},
#                                       'url': 'https://www.last.fm/music/Weezer/_/Butterfly'}]},
#              'url': 'https://www.last.fm/music/Weezer/Pinkerton',
#              'wiki': { 'content': 'Pinkerton is the second studio album by '
#                                   'American alternative rock band Weezer, '
#                                   'released on September 24, 1996 on DGC '
#                                   'Records. Pinkerton was seen as a departure '
#                                   "from the band's original power pop style, "
#                                   'replacing it with a darker, more abrasive '
#                                   'sound  with themes drawn from songwriter '
#                                   "Rivers Cuomo's disillusionment with the "
#                                   'rock lifestyle. It was the last Weezer '
#                                   'album to feature bassist Matt Sharp.\n'
#                                   'Initially a commercial and critical '
#                                   'failure, Pinkerton went on to achieve cult '
#                                   'status and wide acclaim years after its '
#                                   'release. <a '
#                                   'href="http://www.last.fm/music/Weezer/Pinkerton">Read '
#                                   'more on Last.fm</a>. User-contributed text '
#                                   'is available under the Creative Commons '
#                                   'By-SA License; additional terms may apply.',
#                        'published': '23 Jul 2012, 12:02',
#                        'summary': 'Pinkerton is the second studio album by '
#                                   'American alternative rock band Weezer, '
#                                   'released on September 24, 1996 on DGC '
#                                   'Records. Pinkerton was seen as a departure '
#                                   "from the band's original power pop style, "
#                                   'replacing it with a darker, more abrasive '
#                                   'sound  with themes drawn from songwriter '
#                                   "Rivers Cuomo's disillusionment with the "
#                                   'rock lifestyle. It was the last Weezer '
#                                   'album to feature bassist Matt Sharp.\n'
#                                   'Initially a commercial and critical '
#                                   'failure, Pinkerton went on to achieve cult '
#                                   'status and wide acclaim years after its '
#                                   'release. <a '
#                                   'href="http://www.last.fm/music/Weezer/Pinkerton">Read '
#                                   'more on Last.fm</a>.'}}}

# %%
pp.pprint (data['album']['artist'])
# Out:
# 'Weezer'

# %% [markdown]
# # Reading JSON data - Lesson 3 Quiz
#
# Get top listened artist in Japan

# %%
method = 'geo.gettopartists'

country = 'japan'
url = 'http://ws.audioscrobbler.com/2.0/?method={0}&country={1}&api_key=4beab33cc6d65b05800d51f5e83bde1b&format=json'.format(method,country)

lastfm_data = get_data_api(url,'JSON')
pp.pprint (lastfm_data)
# Out:
# { 'topartists': { '@attr': { 'country': 'Japan',
#                              'page': '1',
#                              'perPage': '50',
#                              'total': '513571',
#                              'totalPages': '10272'},
#                   'artist': [ { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/ed22a42245c941c190aca4b6cda19c0d.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/ed22a42245c941c190aca4b6cda19c0d.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/ed22a42245c941c190aca4b6cda19c0d.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/ed22a42245c941c190aca4b6cda19c0d.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/ed22a42245c941c190aca4b6cda19c0d.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3514382',
#                                 'mbid': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#                                 'name': 'The Beatles',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/The+Beatles'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/3a0f627f4717a699fd776cbac336976f.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/3a0f627f4717a699fd776cbac336976f.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/3a0f627f4717a699fd776cbac336976f.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/3a0f627f4717a699fd776cbac336976f.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/3a0f627f4717a699fd776cbac336976f.png',
#                                              'size': 'mega'}],
#                                 'listeners': '341447',
#                                 'mbid': 'b539e453-c4fe-47e3-8a07-8517eac74429',
#                                 'name': '宇多田ヒカル',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E5%AE%87%E5%A4%9A%E7%94%B0%E3%83%92%E3%82%AB%E3%83%AB'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/4d99117807b2c3b29d8ddbac2961e142.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/4d99117807b2c3b29d8ddbac2961e142.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/4d99117807b2c3b29d8ddbac2961e142.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/4d99117807b2c3b29d8ddbac2961e142.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/4d99117807b2c3b29d8ddbac2961e142.png',
#                                              'size': 'mega'}],
#                                 'listeners': '162796',
#                                 'mbid': 'bc471fd0-4e12-49f3-951b-2371b274590d',
#                                 'name': 'Perfume',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Perfume'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/fa5eaff1398d6639fec5436e2c5c2b7b.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/fa5eaff1398d6639fec5436e2c5c2b7b.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/fa5eaff1398d6639fec5436e2c5c2b7b.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/fa5eaff1398d6639fec5436e2c5c2b7b.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/fa5eaff1398d6639fec5436e2c5c2b7b.png',
#                                              'size': 'mega'}],
#                                 'listeners': '4599518',
#                                 'mbid': 'a74b1b7f-71a5-4011-9441-d0b5e4122711',
#                                 'name': 'Radiohead',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Radiohead'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/15b3d7ad48c94915c9cd17f14976360f.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/15b3d7ad48c94915c9cd17f14976360f.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/15b3d7ad48c94915c9cd17f14976360f.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/15b3d7ad48c94915c9cd17f14976360f.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/15b3d7ad48c94915c9cd17f14976360f.png',
#                                              'size': 'mega'}],
#                                 'listeners': '122370',
#                                 'mbid': '9e414497-23b7-4ab7-9ec6-8ea9864c9e87',
#                                 'name': '椎名林檎',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E6%A4%8E%E5%90%8D%E6%9E%97%E6%AA%8E'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/17ba094f35249c032ee427d35e45c10a.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/17ba094f35249c032ee427d35e45c10a.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/17ba094f35249c032ee427d35e45c10a.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/17ba094f35249c032ee427d35e45c10a.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/17ba094f35249c032ee427d35e45c10a.png',
#                                              'size': 'mega'}],
#                                 'listeners': '91070',
#                                 'mbid': '0550993e-ddec-468e-b05f-da81bf6f7694',
#                                 'name': 'スピッツ',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E3%82%B9%E3%83%94%E3%83%83%E3%83%84'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/09079ce485e5483aa691ed3a38848420.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/09079ce485e5483aa691ed3a38848420.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/09079ce485e5483aa691ed3a38848420.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/09079ce485e5483aa691ed3a38848420.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/09079ce485e5483aa691ed3a38848420.png',
#                                              'size': 'mega'}],
#                                 'listeners': '244385',
#                                 'mbid': '14e410f5-97f2-48ba-b1f7-a3a44cbea05c',
#                                 'name': 'ASIAN KUNG-FU GENERATION',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/ASIAN+KUNG-FU+GENERATION'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/9d4d11975b9247ff991e636ac5ace613.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/9d4d11975b9247ff991e636ac5ace613.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/9d4d11975b9247ff991e636ac5ace613.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/9d4d11975b9247ff991e636ac5ace613.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/9d4d11975b9247ff991e636ac5ace613.png',
#                                              'size': 'mega'}],
#                                 'listeners': '61383',
#                                 'mbid': '252c9f8a-be04-4146-b73e-a24696b2f5ed',
#                                 'name': 'くるり',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E3%81%8F%E3%82%8B%E3%82%8A'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/a1cbb41cac2c4225ffc45ec56a73fa83.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/a1cbb41cac2c4225ffc45ec56a73fa83.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/a1cbb41cac2c4225ffc45ec56a73fa83.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/a1cbb41cac2c4225ffc45ec56a73fa83.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/a1cbb41cac2c4225ffc45ec56a73fa83.png',
#                                              'size': 'mega'}],
#                                 'listeners': '36790',
#                                 'mbid': '01830cc1-8a04-4dfb-9e4a-d557dfda6a93',
#                                 'name': 'サカナクション',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E3%82%B5%E3%82%AB%E3%83%8A%E3%82%AF%E3%82%B7%E3%83%A7%E3%83%B3'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/9e26b6e7282d4c52cca398b28c7e57b5.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/9e26b6e7282d4c52cca398b28c7e57b5.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/9e26b6e7282d4c52cca398b28c7e57b5.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/9e26b6e7282d4c52cca398b28c7e57b5.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/9e26b6e7282d4c52cca398b28c7e57b5.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3217917',
#                                 'mbid': '5441c29d-3602-4898-b1a1-b77fa23b8e50',
#                                 'name': 'David Bowie',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/David+Bowie'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/08300481d8484150c13b769007cac3ef.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/08300481d8484150c13b769007cac3ef.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/08300481d8484150c13b769007cac3ef.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/08300481d8484150c13b769007cac3ef.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/08300481d8484150c13b769007cac3ef.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3472457',
#                                 'mbid': 'ecf9f3a3-35e9-4c58-acaa-e707fba45060',
#                                 'name': 'Oasis',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Oasis'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/97cef8d9022d4b13ab7d84ab392c7c8f.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/97cef8d9022d4b13ab7d84ab392c7c8f.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/97cef8d9022d4b13ab7d84ab392c7c8f.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/97cef8d9022d4b13ab7d84ab392c7c8f.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/97cef8d9022d4b13ab7d84ab392c7c8f.png',
#                                              'size': 'mega'}],
#                                 'listeners': '100082',
#                                 'mbid': '0f718079-e5ea-4cfb-b512-b2d04da66901',
#                                 'name': 'BUMP OF CHICKEN',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/BUMP+OF+CHICKEN'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/2368d78350d34561914609a9cecd1b52.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/2368d78350d34561914609a9cecd1b52.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/2368d78350d34561914609a9cecd1b52.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/2368d78350d34561914609a9cecd1b52.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/2368d78350d34561914609a9cecd1b52.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3391480',
#                                 'mbid': 'a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432',
#                                 'name': 'U2',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/U2'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/c4131190e798435a9416486a259ca19d.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/c4131190e798435a9416486a259ca19d.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/c4131190e798435a9416486a259ca19d.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/c4131190e798435a9416486a259ca19d.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/c4131190e798435a9416486a259ca19d.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3818927',
#                                 'mbid': '420ca290-76c5-41af-999e-564d7c71f1a7',
#                                 'name': 'Queen',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Queen'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/211c21be6e18477b92e8f9c63a720cbc.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/211c21be6e18477b92e8f9c63a720cbc.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/211c21be6e18477b92e8f9c63a720cbc.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/211c21be6e18477b92e8f9c63a720cbc.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/211c21be6e18477b92e8f9c63a720cbc.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3664332',
#                                 'mbid': '056e4f3e-d505-4dad-8ec1-d04f521cbb56',
#                                 'name': 'Daft Punk',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Daft+Punk'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/421cac7d8e42662f069c4b69e7934d7b.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/421cac7d8e42662f069c4b69e7934d7b.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/421cac7d8e42662f069c4b69e7934d7b.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/421cac7d8e42662f069c4b69e7934d7b.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/421cac7d8e42662f069c4b69e7934d7b.png',
#                                              'size': 'mega'}],
#                                 'listeners': '5230145',
#                                 'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#                                 'name': 'Coldplay',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Coldplay'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/290267f3040041ea9ff4a908c3912ef6.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/290267f3040041ea9ff4a908c3912ef6.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/290267f3040041ea9ff4a908c3912ef6.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/290267f3040041ea9ff4a908c3912ef6.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/290267f3040041ea9ff4a908c3912ef6.png',
#                                              'size': 'mega'}],
#                                 'listeners': '93747',
#                                 'mbid': 'b3d0f168-cb34-47c6-8529-fc05d1fce3ee',
#                                 'name': '東京事変',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E6%9D%B1%E4%BA%AC%E4%BA%8B%E5%A4%89'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/71fb1d7f7c324f259428f207211b8e4d.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/71fb1d7f7c324f259428f207211b8e4d.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/71fb1d7f7c324f259428f207211b8e4d.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/71fb1d7f7c324f259428f207211b8e4d.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/71fb1d7f7c324f259428f207211b8e4d.png',
#                                              'size': 'mega'}],
#                                 'listeners': '88594',
#                                 'mbid': '27f0af0e-4d1f-4808-a58b-090e400dcc43',
#                                 'name': 'Mr.Children',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Mr.Children'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/13c90c61d0bc47fd9f391831552a94b2.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/13c90c61d0bc47fd9f391831552a94b2.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/13c90c61d0bc47fd9f391831552a94b2.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/13c90c61d0bc47fd9f391831552a94b2.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/13c90c61d0bc47fd9f391831552a94b2.png',
#                                              'size': 'mega'}],
#                                 'listeners': '4481480',
#                                 'mbid': '8bfac288-ccc5-448d-9573-c33ea2aa5c30',
#                                 'name': 'Red Hot Chili Peppers',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Red+Hot+Chili+Peppers'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/5ac3ae19a6d2de61402dd169f8b0ed08.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/5ac3ae19a6d2de61402dd169f8b0ed08.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/5ac3ae19a6d2de61402dd169f8b0ed08.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/5ac3ae19a6d2de61402dd169f8b0ed08.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/5ac3ae19a6d2de61402dd169f8b0ed08.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3392670',
#                                 'mbid': 'f27ec8db-af05-4f36-916e-3d57f91ecf5e',
#                                 'name': 'Michael Jackson',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Michael+Jackson'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/feab711a7cf308deb8586914ed1784bd.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/feab711a7cf308deb8586914ed1784bd.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/feab711a7cf308deb8586914ed1784bd.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/feab711a7cf308deb8586914ed1784bd.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/feab711a7cf308deb8586914ed1784bd.png',
#                                              'size': 'mega'}],
#                                 'listeners': '80692',
#                                 'mbid': '6f500293-7396-4903-b4fd-118127d06f9e',
#                                 'name': 'RADWIMPS',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/RADWIMPS'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/95412fa74fb1469aa08b5b00f5e82e30.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/95412fa74fb1469aa08b5b00f5e82e30.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/95412fa74fb1469aa08b5b00f5e82e30.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/95412fa74fb1469aa08b5b00f5e82e30.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/95412fa74fb1469aa08b5b00f5e82e30.png',
#                                              'size': 'mega'}],
#                                 'listeners': '58737',
#                                 'mbid': '8f026642-9e02-4f1b-880d-0ae7894a3e92',
#                                 'name': 'フジファブリック',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E3%83%95%E3%82%B8%E3%83%95%E3%82%A1%E3%83%96%E3%83%AA%E3%83%83%E3%82%AF'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/854877b5149ef65a3af281d9a46a3209.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/854877b5149ef65a3af281d9a46a3209.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/854877b5149ef65a3af281d9a46a3209.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/854877b5149ef65a3af281d9a46a3209.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/854877b5149ef65a3af281d9a46a3209.png',
#                                              'size': 'mega'}],
#                                 'listeners': '12330',
#                                 'mbid': '2c6c53ea-09d4-4d98-b174-c9aa83d4fecf',
#                                 'name': '星野源',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E6%98%9F%E9%87%8E%E6%BA%90'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/c43b3f5395c994543fd636a1c09ea85d.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/c43b3f5395c994543fd636a1c09ea85d.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/c43b3f5395c994543fd636a1c09ea85d.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/c43b3f5395c994543fd636a1c09ea85d.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/c43b3f5395c994543fd636a1c09ea85d.png',
#                                              'size': 'mega'}],
#                                 'listeners': '50993',
#                                 'mbid': '0d27f48b-c8d7-464b-85e5-5a2b823436c9',
#                                 'name': '松任谷由実',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E6%9D%BE%E4%BB%BB%E8%B0%B7%E7%94%B1%E5%AE%9F'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/dda6de9c77df43aaaf7d19863dace826.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/dda6de9c77df43aaaf7d19863dace826.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/dda6de9c77df43aaaf7d19863dace826.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/dda6de9c77df43aaaf7d19863dace826.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/dda6de9c77df43aaaf7d19863dace826.png',
#                                              'size': 'mega'}],
#                                 'listeners': '4136646',
#                                 'mbid': '9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6',
#                                 'name': 'Nirvana',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Nirvana'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/610e4682f7098bc584df98d0154a4f81.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/610e4682f7098bc584df98d0154a4f81.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/610e4682f7098bc584df98d0154a4f81.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/610e4682f7098bc584df98d0154a4f81.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/610e4682f7098bc584df98d0154a4f81.png',
#                                              'size': 'mega'}],
#                                 'listeners': '2832530',
#                                 'mbid': 'a8baaa41-50f1-4f63-979e-717c14979dfb',
#                                 'name': 'Beck',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Beck'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/24eda094bf55463589a465521c368990.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/24eda094bf55463589a465521c368990.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/24eda094bf55463589a465521c368990.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/24eda094bf55463589a465521c368990.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/24eda094bf55463589a465521c368990.png',
#                                              'size': 'mega'}],
#                                 'listeners': '1580461',
#                                 'mbid': 'f4857fb9-e255-4dc6-bd01-e4ca7cc68544',
#                                 'name': 'Jamiroquai',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Jamiroquai'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/61405a4353eefbf2d6a546d6eb7fcab1.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/61405a4353eefbf2d6a546d6eb7fcab1.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/61405a4353eefbf2d6a546d6eb7fcab1.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/61405a4353eefbf2d6a546d6eb7fcab1.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/61405a4353eefbf2d6a546d6eb7fcab1.png',
#                                              'size': 'mega'}],
#                                 'listeners': '44144',
#                                 'mbid': '176650bf-db9c-48dd-8c01-376104966997',
#                                 'name': '電気グルーヴ',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E9%9B%BB%E6%B0%97%E3%82%B0%E3%83%AB%E3%83%BC%E3%83%B4'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/796b2bb8d53857163d54d3b510d8e5d1.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/796b2bb8d53857163d54d3b510d8e5d1.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/796b2bb8d53857163d54d3b510d8e5d1.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/796b2bb8d53857163d54d3b510d8e5d1.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/796b2bb8d53857163d54d3b510d8e5d1.png',
#                                              'size': 'mega'}],
#                                 'listeners': '36401',
#                                 'mbid': 'ead227f6-7689-46b6-9fd2-3f6a37acbdc1',
#                                 'name': '相対性理論',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E7%9B%B8%E5%AF%BE%E6%80%A7%E7%90%86%E8%AB%96'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/00f64aaa592ae51810dec0b29a108316.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/00f64aaa592ae51810dec0b29a108316.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/00f64aaa592ae51810dec0b29a108316.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/00f64aaa592ae51810dec0b29a108316.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/00f64aaa592ae51810dec0b29a108316.png',
#                                              'size': 'mega'}],
#                                 'listeners': '107314',
#                                 'mbid': 'c45f4716-448b-42ef-8e56-1d711672077b',
#                                 'name': 'YUKI',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/YUKI'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/eb205af6ed7b4d428cd42351f9c496a5.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/eb205af6ed7b4d428cd42351f9c496a5.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/eb205af6ed7b4d428cd42351f9c496a5.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/eb205af6ed7b4d428cd42351f9c496a5.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/eb205af6ed7b4d428cd42351f9c496a5.png',
#                                              'size': 'mega'}],
#                                 'listeners': '2802024',
#                                 'mbid': 'd6e0e274-8e19-44ce-b5b2-52c12f8a674a',
#                                 'name': 'Led Zeppelin',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Led+Zeppelin'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/27580162653c478daf7d8bb22f75916d.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/27580162653c478daf7d8bb22f75916d.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/27580162653c478daf7d8bb22f75916d.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/27580162653c478daf7d8bb22f75916d.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/27580162653c478daf7d8bb22f75916d.png',
#                                              'size': 'mega'}],
#                                 'listeners': '2037827',
#                                 'mbid': 'c1aa2ec9-53e7-4d90-8d36-bac75832e986',
#                                 'name': 'Stevie Wonder',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Stevie+Wonder'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/99cde093db2d0c5ae9ab02b1682f0d47.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/99cde093db2d0c5ae9ab02b1682f0d47.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/99cde093db2d0c5ae9ab02b1682f0d47.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/99cde093db2d0c5ae9ab02b1682f0d47.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/99cde093db2d0c5ae9ab02b1682f0d47.png',
#                                              'size': 'mega'}],
#                                 'listeners': '2127329',
#                                 'mbid': '87c5dedd-371d-4a53-9f7f-80522fb7f3cb',
#                                 'name': 'Björk',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Bj%C3%B6rk'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/3b9922069cdf4e69a9bb8ad64095cf74.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/3b9922069cdf4e69a9bb8ad64095cf74.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/3b9922069cdf4e69a9bb8ad64095cf74.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/3b9922069cdf4e69a9bb8ad64095cf74.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/3b9922069cdf4e69a9bb8ad64095cf74.png',
#                                              'size': 'mega'}],
#                                 'listeners': '1441678',
#                                 'mbid': 'f22942a1-6f70-4f48-866e-238cb2308fbd',
#                                 'name': 'Aphex Twin',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Aphex+Twin'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/32be47a41e904dbcbcfc094ed6b970af.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/32be47a41e904dbcbcfc094ed6b970af.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/32be47a41e904dbcbcfc094ed6b970af.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/32be47a41e904dbcbcfc094ed6b970af.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/32be47a41e904dbcbcfc094ed6b970af.png',
#                                              'size': 'mega'}],
#                                 'listeners': '59072',
#                                 'mbid': '3a297fc0-7c88-4d2b-894f-0bbc07a33099',
#                                 'name': 'チャットモンチー',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E3%83%81%E3%83%A3%E3%83%83%E3%83%88%E3%83%A2%E3%83%B3%E3%83%81%E3%83%BC'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/ecaf025cbd3b482bbd5dbdbcb4fc7cf0.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/ecaf025cbd3b482bbd5dbdbcb4fc7cf0.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/ecaf025cbd3b482bbd5dbdbcb4fc7cf0.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/ecaf025cbd3b482bbd5dbdbcb4fc7cf0.png',
#                                              'size': 'extralarge'},
# ...
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/299d2d8dcfe43deaee108f1c4790e877.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/299d2d8dcfe43deaee108f1c4790e877.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/299d2d8dcfe43deaee108f1c4790e877.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/299d2d8dcfe43deaee108f1c4790e877.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/299d2d8dcfe43deaee108f1c4790e877.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3853305',
#                                 'mbid': 'f59c5520-5f46-4d2c-b2c4-822eabf53419',
#                                 'name': 'Linkin Park',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Linkin+Park'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/313950bfa7164d70a5aba38b3baa5e4e.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/313950bfa7164d70a5aba38b3baa5e4e.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/313950bfa7164d70a5aba38b3baa5e4e.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/313950bfa7164d70a5aba38b3baa5e4e.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/313950bfa7164d70a5aba38b3baa5e4e.png',
#                                              'size': 'mega'}],
#                                 'listeners': '2776157',
#                                 'mbid': 'ba853904-ae25-4ebb-89d6-c44cfbd71bd2',
#                                 'name': 'Blur',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Blur'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/70952d8deedd6f3a3231d064ee8387fa.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/70952d8deedd6f3a3231d064ee8387fa.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/70952d8deedd6f3a3231d064ee8387fa.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/70952d8deedd6f3a3231d064ee8387fa.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/70952d8deedd6f3a3231d064ee8387fa.png',
#                                              'size': 'mega'}],
#                                 'listeners': '101846',
#                                 'mbid': '27e2997f-f7a1-4353-bcc4-57b9274fa9a4',
#                                 'name': 'BABYMETAL',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/BABYMETAL'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/152cae0243ae4c68952c9b762abe8319.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/152cae0243ae4c68952c9b762abe8319.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/152cae0243ae4c68952c9b762abe8319.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/152cae0243ae4c68952c9b762abe8319.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/152cae0243ae4c68952c9b762abe8319.png',
#                                              'size': 'mega'}],
#                                 'listeners': '82949',
#                                 'mbid': 'f4f40cba-d1f4-4e4e-baea-d8145664916c',
#                                 'name': 'Supercar',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Supercar'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/3e8102f274934fa98035e2b2f70f9242.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/3e8102f274934fa98035e2b2f70f9242.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/3e8102f274934fa98035e2b2f70f9242.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/3e8102f274934fa98035e2b2f70f9242.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/3e8102f274934fa98035e2b2f70f9242.png',
#                                              'size': 'mega'}],
#                                 'listeners': '2570340',
#                                 'mbid': '72c536dc-7137-4477-a521-567eeb840fa8',
#                                 'name': 'Bob Dylan',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Bob+Dylan'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/6e7eac3310bbf128cbae2c4c17443849.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/6e7eac3310bbf128cbae2c4c17443849.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/6e7eac3310bbf128cbae2c4c17443849.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/6e7eac3310bbf128cbae2c4c17443849.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/6e7eac3310bbf128cbae2c4c17443849.png',
#                                              'size': 'mega'}],
#                                 'listeners': '3675774',
#                                 'mbid': 'b071f9fa-14b0-4217-8e97-eb41da73f598',
#                                 'name': 'The Rolling Stones',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/The+Rolling+Stones'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/d95241def3668dfb3a36c302702c256d.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/d95241def3668dfb3a36c302702c256d.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/d95241def3668dfb3a36c302702c256d.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/d95241def3668dfb3a36c302702c256d.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/d95241def3668dfb3a36c302702c256d.png',
#                                              'size': 'mega'}],
#                                 'listeners': '384171',
#                                 'mbid': 'a7f7df4a-77d8-4f12-8acd-5c60c93f4de8',
#                                 'name': '坂本龍一',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E5%9D%82%E6%9C%AC%E9%BE%8D%E4%B8%80'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/772b1e800c4849eea429c5b424801faa.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/772b1e800c4849eea429c5b424801faa.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/772b1e800c4849eea429c5b424801faa.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/772b1e800c4849eea429c5b424801faa.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/772b1e800c4849eea429c5b424801faa.png',
#                                              'size': 'mega'}],
#                                 'listeners': '31474',
#                                 'mbid': 'ad62391d-ab7e-4ac9-9ce8-3704bc6746bb',
#                                 'name': '山下達郎',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/%E5%B1%B1%E4%B8%8B%E9%81%94%E9%83%8E'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/8369b21a2af5c2b59199af2e02b1c276.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/8369b21a2af5c2b59199af2e02b1c276.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/8369b21a2af5c2b59199af2e02b1c276.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/8369b21a2af5c2b59199af2e02b1c276.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/8369b21a2af5c2b59199af2e02b1c276.png',
#                                              'size': 'mega'}],
#                                 'listeners': '1719762',
#                                 'mbid': 'f1106b17-dcbb-45f6-b938-199ccfab50cc',
#                                 'name': 'New Order',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/New+Order'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/398f10e846a4415197dd4d9f4c67b404.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/398f10e846a4415197dd4d9f4c67b404.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/398f10e846a4415197dd4d9f4c67b404.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/398f10e846a4415197dd4d9f4c67b404.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/398f10e846a4415197dd4d9f4c67b404.png',
#                                              'size': 'mega'}],
#                                 'listeners': '271770',
#                                 'mbid': '',
#                                 'name': "L'Arc~en~Ciel",
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/L%27Arc~en~Ciel'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/06e17f62a40d9df85ad64c94ac715097.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/06e17f62a40d9df85ad64c94ac715097.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/06e17f62a40d9df85ad64c94ac715097.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/06e17f62a40d9df85ad64c94ac715097.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/06e17f62a40d9df85ad64c94ac715097.png',
#                                              'size': 'mega'}],
#                                 'listeners': '2733037',
#                                 'mbid': 'cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493',
#                                 'name': 'Adele',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Adele'},
#                               { 'image': [ { '#text': 'https://lastfm-img2.akamaized.net/i/u/34s/f329632095864a88a4e77a2f32521080.png',
#                                              'size': 'small'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/64s/f329632095864a88a4e77a2f32521080.png',
#                                              'size': 'medium'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/174s/f329632095864a88a4e77a2f32521080.png',
#                                              'size': 'large'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/f329632095864a88a4e77a2f32521080.png',
#                                              'size': 'extralarge'},
#                                            { '#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/f329632095864a88a4e77a2f32521080.png',
#                                              'size': 'mega'}],
#                                 'listeners': '124311',
#                                 'mbid': 'dc879b7e-7560-4b72-975e-0799476c68cc',
#                                 'name': 'Capsule',
#                                 'streamable': '0',
#                                 'url': 'https://www.last.fm/music/Capsule'}]}}

# %%
top_spain_artist = lastfm_data['topartists']['artist'][0]['name']
pp.pprint (top_spain_artist)
# Out:
# 'The Beatles'

# %% [markdown]
# # Sanity Checking Data
#
# * Does the data make sense?
# * Is there a problem?
# * Does the data look like I expect it to?
#
# -> Udacity Exploratory Data Analysis Course

# %% [markdown]
# ## Pandas DataFrame Describe
#
# Get info about DataFrame and helps to check the data (mitigate the effect of missing/inconsistent values...)

# %%
baseball_data = pd.read_csv(input_dir + 'baseballdatabank-2017.1/core/Master.csv')

# %%
baseball_data.describe()
# Out:
#           birthYear    birthMonth      birthDay    deathYear   deathMonth  \
# count  18973.000000  18803.000000  18656.000000  9441.000000  9440.000000
# mean    1931.435356      6.629474     15.614816  1964.287364     6.483581
# std       41.555514      3.468103      8.750216    31.808030     3.529655
# min     1820.000000      1.000000      1.000000  1872.000000     1.000000
# 25%     1895.000000      4.000000      8.000000  1942.000000     3.000000
# 50%     1937.000000      7.000000     16.000000  1967.000000     6.000000
# 75%     1969.000000     10.000000     23.000000  1990.000000    10.000000
# max     1996.000000     12.000000     31.000000  2017.000000    12.000000
#
#           deathDay        weight        height
# count  9439.000000  18251.000000  18320.000000
# mean     15.569552    186.375596     72.273799
# std       8.779552     21.524765      2.603904
# min       1.000000     65.000000     43.000000
# 25%       8.000000    170.000000     71.000000
# 50%      15.000000    185.000000     72.000000
# 75%      23.000000    200.000000     74.000000
# max      31.000000    320.000000     83.000000

# %% [markdown]
# ### Dealing with Missing Data
# #### Partial Deletion
# * <b>Listwise Deletion:</b> delete the entire row that is missing data
# * <b>Pairwise Deletion:</b> delete for particular case
#
# #### Imputation (why?)
# * Not much data
# * Removing data could effect representativeness
#
# ##### Many different imputation techniques (really hard to get right)

# %% [markdown]
# ### (Simple) Imputation methods
# Filling missing values
# * Use mean value (column)
#
#
# * Linear regression:
#
# 1) Train a linear model using the data we have
#
# 2) Make an equation to predict variable with missing values
#
# 3) Predict missing values
#
# ##### They both have negative side effects and can obscure/amplify trends in data

# %% [markdown]
# ## Pandas DataFrame method: fillna(value)
# Pass in a static value to replace any NAs in DataFrame or Series
# * dataframe['column'] = dataframe['column'].fillna(value)

# %% [markdown]
# # Impute mean value exercise Lesson 3 Quiz

# %% [markdown]
# Using the amazing NumPy

# %%
def fill_df_na(df, col_name, fill):
    df[col_name] = df[col_name].fillna(fill)
    
    return df

# %%
m_weight = np.mean(baseball_data['weight'])
baseball_data = fill_df_na(baseball_data, 'weight', m_weight)

# %%
print (baseball_data['weight'])
# Out:
# 0        215.000000
# 1        180.000000
# 2        190.000000
# 3        190.000000
# 4        184.000000
# 5        220.000000
# 6        192.000000
# 7        170.000000
# 8        175.000000
# 9        169.000000
# 10       190.000000
# 11       180.000000
# 12       200.000000
# 13       190.000000
# 14       200.000000
# 15       180.000000
# 16       200.000000
# 17       180.000000
# 18       185.000000
# 19       195.000000
# 20       186.375596
# 21       215.000000
# 22       190.000000
# 23       185.000000
# 24       210.000000
# 25       215.000000
# 26       170.000000
# 27       200.000000
# 28       200.000000
# 29       190.000000
#             ...
# 19075    225.000000
# 19076    187.000000
# 19077    225.000000
# 19078    190.000000
# 19079    165.000000
# 19080    150.000000
# 19081    170.000000
# 19082    195.000000
# 19083    185.000000
# 19084    200.000000
# 19085    200.000000
# 19086    200.000000
# 19087    205.000000
# 19088    175.000000
# 19089    180.000000
# 19090    210.000000
# 19091    200.000000
# 19092    185.000000
# 19093    175.000000
# 19094    195.000000
# 19095    190.000000
# 19096    230.000000
# 19097    215.000000
# 19098    220.000000
# 19099    220.000000
# 19100    182.000000
# 19101    173.000000
# 19102    195.000000
# 19103    160.000000
# 19104    190.000000
# Name: weight, Length: 19105, dtype: float64
